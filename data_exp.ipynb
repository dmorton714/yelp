# %%
import pandas as pd

# %%
df = pd.read_csv('yelp.csv')
df.head()
# Out:
#    Unnamed: 0                               Name  Rating  Review Count Price  \
# 0           0                        Hammerheads     4.5          1323    $$
# 1           1                          The Eagle     4.5          1507    $$
# 2           2                         Doc Crow's     4.0          2017    $$
# 3           3                   North of Bourbon     4.5           132    $$
# 4           4  Oliver's Chop House & Bourbon Bar     4.5             3   NaN
#
#                                              Address
# 0                  921 Swan St, Louisville, KY 40204
# 1            1314 Bardstown Rd, Louisville, KY 40204
# 2                127 W Main St, Louisville, KY 40202
# 3                 935 Goss Ave, Louisville, KY 40217
# 4  4520 Poplar Level Rd, Derby City Gaming Hotel,...

# %%
df = df.sort_values(by="Rating", ascending=True)
df.head()
# Out:
#      Unnamed: 0                             Name  Rating  Review Count Price  \
# 504         504                     Antojitos JJ     0.0             0   NaN
# 949         949                   8th Lane Grill     0.0             0   NaN
# 701         701              Grubbin at Da Spott     0.0             0   NaN
# 523         523  Orleans Authentic Cajun Cuisine     0.0             0   NaN
# 936         936                        Dank Dogs     0.0             0   NaN
#
#                                               Address
# 504              1032 Story Ave, Louisville, KY 40206
# 949  1000 Auction Ln, Ste B, Jeffersonville, IN 47130
# 701              1612 Dixie Hwy, Louisville, KY 40210
# 523    1812 W Muhammad Ali Blvd, Louisville, KY 40203
# 936           1132 Bardstown Rd, Louisville, KY 40204

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 504 to 524
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1000 non-null   int64
#  1   Name          1000 non-null   object
#  2   Rating        1000 non-null   float64
#  3   Review Count  1000 non-null   int64
#  4   Price         667 non-null    object
#  5   Address       1000 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 54.7+ KB

# %%
# condition = df["Rating"] == 0.0

# # Hide the Rating column value where the condition is True
# df["Rating"] = df["Rating"].mask(condition, "Hidden")

# # Print the modified DataFrame
# df.head()

# %%
df = df.loc[df["Rating"] != 0.0]

# Reset the index of the modified DataFrame
df = df.reset_index(drop=True)

df.head()
# Out:
#    Unnamed: 0                        Name  Rating  Review Count Price  \
# 0         301            Afrokanza Lounge     1.0             1   NaN
# 1         460  Griyo Caribbean Restaurant     1.0             3   NaN
# 2         682              Steak ’n Shake     1.5           101     $
# 3         881                  McDonald's     1.5            78     $
# 4         696                 Dairy Queen     1.5            48     $
#
#                                       Address
# 0     1578 Bardstown Rd, Louisville, KY 40205
# 1          519 W Oak St, Louisville, KY 40203
# 2         4545 Outer Lp, Louisville, KY 40219
# 3     1245 Bardstown Rd, Louisville, KY 40204
# 4  3221 Poplar Level Rd, Louisville, KY 40213

# %%
df.to_json('yelp.json')
